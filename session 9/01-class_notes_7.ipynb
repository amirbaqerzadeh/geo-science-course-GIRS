# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
# upload data to jupyter notebook
file_pattern = "./data/data_*.xlsx"
excel_files = glob.glob(file_pattern)

# %%
type(excel_files)
# Out:
# list

# %%
excel_files
# Out:
# ['./data/data_5.xlsx',
#  './data/data_6.xlsx',
#  './data/data_3.xlsx',
#  './data/data_1.xlsx',
#  './data/data_2.xlsx',
#  './data/data_4.xlsx']

# %%
# df1 = pd.read_excel(excel_files[0])

# %%
# create a list of dfs
dfs = []
for file in excel_files:
    df = pd.read_excel(file)
    dfs.append(df)

# %%
dfs[0].head()
# Out:
#                   date                                     contentmessage
# 0  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
# 1  2024-01-20 03:00:00  AAXX 20031 40751 42960 00402 10030 21064 38498...
# 2  2024-01-20 06:00:00  AAXX 20061 40751 12960 42201 10100 21044 38506...
# 3  2024-01-20 09:00:00  AAXX 20091 40751 42960 41802 10111 21054 38496...
# 4  2024-01-20 12:00:00  AAXX 20121 40751 12960 01901 10120 21049 38485...

# %%
len(dfs)
# Out:
# 6

# %%
dfs[5].tail()
# Out:
#                     date                                     contentmessage
# 244  2024-01-19 12:00:00  AAXX 19121 40751 12960 02101 10128 21045 38485...
# 245  2024-01-19 15:00:00  AAXX 19151 40751 42960 00000 10068 21049 38493...
# 246  2024-01-19 18:00:00  AAXX 19181 40751 12960 00401 10057 21044 38498...
# 247  2024-01-19 21:00:00  AAXX 19211 40751 42960 00402 10038 21054 38496...
# 248  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...

# %%
df = pd.concat(dfs, ignore_index=True)

# %%
df.head()
# Out:
#                   date                                     contentmessage
# 0  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
# 1  2024-01-20 03:00:00  AAXX 20031 40751 42960 00402 10030 21064 38498...
# 2  2024-01-20 06:00:00  AAXX 20061 40751 12960 42201 10100 21044 38506...
# 3  2024-01-20 09:00:00  AAXX 20091 40751 42960 41802 10111 21054 38496...
# 4  2024-01-20 12:00:00  AAXX 20121 40751 12960 01901 10120 21049 38485...

# %%
df.tail()
# Out:
#                      date                                     contentmessage
# 1457  2024-01-19 12:00:00  AAXX 19121 40751 12960 02101 10128 21045 38485...
# 1458  2024-01-19 15:00:00  AAXX 19151 40751 42960 00000 10068 21049 38493...
# 1459  2024-01-19 18:00:00  AAXX 19181 40751 12960 00401 10057 21044 38498...
# 1460  2024-01-19 21:00:00  AAXX 19211 40751 42960 00402 10038 21054 38496...
# 1461  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1462 non-null   object
#  1   contentmessage  1458 non-null   object
# dtypes: object(2)
# memory usage: 23.0+ KB

# %%
# find null rows
df[df.isnull().any(axis=1)]
# Out:
#                      date contentmessage
# 120   2024-02-04 00:00:00            NaN
# 132   2024-02-05 12:00:00            NaN
# 982   2023-10-22 06:00:00            NaN
# 1157  2023-11-13 03:00:00            NaN

# %%
# delete NaN
df = df.dropna(subset='contentmessage')

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [date, contentmessage]
# Index: []

# %%
df.tail()
# Out:
#                      date                                     contentmessage
# 1457  2024-01-19 12:00:00  AAXX 19121 40751 12960 02101 10128 21045 38485...
# 1458  2024-01-19 15:00:00  AAXX 19151 40751 42960 00000 10068 21049 38493...
# 1459  2024-01-19 18:00:00  AAXX 19181 40751 12960 00401 10057 21044 38498...
# 1460  2024-01-19 21:00:00  AAXX 19211 40751 42960 00402 10038 21054 38496...
# 1461  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.tail()
# Out:
#                      date                                     contentmessage
# 1453  2024-01-19 12:00:00  AAXX 19121 40751 12960 02101 10128 21045 38485...
# 1454  2024-01-19 15:00:00  AAXX 19151 40751 42960 00000 10068 21049 38493...
# 1455  2024-01-19 18:00:00  AAXX 19181 40751 12960 00401 10057 21044 38498...
# 1456  2024-01-19 21:00:00  AAXX 19211 40751 42960 00402 10038 21054 38496...
# 1457  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...

# %%
s1 = df.iloc[200]['contentmessage']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s1 = df.iloc[200]['contentmessage']
#
# NameError: name 'df' is not defined

# %%
type(s1)
# Out:
# str

# %%
s1
# Out:
# 'AAXX 14061 40751 12960 32001 10169 21038 38485 40167 52009 60001 83030 333 30002 5//// 70000 83360 555 10080 29024='

# %%
s1.find('10105')
# Out:
# -1

# %%
temp_idx = 29
s1[temp_idx:temp_idx+5]
# Out:
# '10169'

# %%
def extract_temp(s):
    temp = 0
    temp_idx = 29
    s = s[temp_idx:temp_idx+5]
    if s[1] == '0':
        return float(s[2:]) / 10

    elif s[1] == '1':
        return -float(s[2:]) / 10

# %%
extract_temp(s1)
# Out:
# 16.9

# %%
# apply extract_temp function on df
df1 = df.copy()
df1['temp'] = df1['contentmessage'].apply(extract_temp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 # apply extract_temp function on df
#       2 df1 = df.copy()
# ----> 3 df1['temp'] = df1['contentmessage'].apply(extract_temp)
#
# File ~/miniconda3/envs/test/lib/python3.13/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/miniconda3/envs/test/lib/python3.13/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniconda3/envs/test/lib/python3.13/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/test/lib/python3.13/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/test/lib/python3.13/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[34], line 5, in extract_temp(s)
#       3 temp_idx = 29
#       4 s = s[temp_idx:temp_idx+5]
# ----> 5 if s[1] == '0':
#       6     return float(s[2:]) / 10
#       8 elif s[1] == '1':
#
# IndexError: string index out of range

# %%
a = df.iloc[0:11]

# %%
a['temp'] = a['contentmessage'].apply(extract_temp)
# Out:
# /tmp/ipykernel_147359/3316087897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['temp'] = a['contentmessage'].apply(extract_temp)

# %%
a
# Out:
#                    date                                     contentmessage  \
# 0   2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
# 1   2024-01-20 03:00:00  AAXX 20031 40751 42960 00402 10030 21064 38498...
# 2   2024-01-20 06:00:00  AAXX 20061 40751 12960 42201 10100 21044 38506...
# 3   2024-01-20 09:00:00  AAXX 20091 40751 42960 41802 10111 21054 38496...
# 4   2024-01-20 12:00:00  AAXX 20121 40751 12960 01901 10120 21049 38485...
# 5   2024-01-20 15:00:00  AAXX 20151 40751 42960 20000 10069 21048 38493...
# 6   2024-01-20 18:00:00  AAXX 20181 40751 12960 00301 10054 21037 38492...
# 7   2024-01-20 21:00:00  AAXX 20211 40751 42960 00401 10037 21040 38486...
# 8   2024-01-21 00:00:00  AAXX 21001 40751 12960 00302 10027 21047 38479...
# 9   2024-01-21 03:00:00  AAXX 21031 40751 42960 00301 10025 21061 38474...
# 10  2024-01-21 06:00:00  AAXX 21061 40751 12960 01701 10113 21056 38487...
#
#     temp
# 0    2.6
# 1    3.0
# 2   10.0
# 3   11.1
# 4   12.0
# 5    6.9
# 6    5.4
# 7    3.7
# 8    2.7
# 9    2.5
# 10  11.3

# %%
def extract_temp(s):
    temp_idx = 29
    if len(s) >=temp_idx + 5:        
        s = s[temp_idx:temp_idx+5]

        
        if s.isdigit() and s[0] in ['1']:
            if s[1] == '0':
                return float(s[1:]) / 10
            elif s[1] == '1':
                return -float(s[1:]) /10
        else:
            return np.nan
    else:
        return np.nan

# %%
# apply extract_temp function on df
df1 = df.copy()
df1['temp'] = df1['contentmessage'].apply(extract_temp)

# %%
df1.head()
# Out:
#                   date                                     contentmessage  \
# 0  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
# 1  2024-01-20 03:00:00  AAXX 20031 40751 42960 00402 10030 21064 38498...
# 2  2024-01-20 06:00:00  AAXX 20061 40751 12960 42201 10100 21044 38506...
# 3  2024-01-20 09:00:00  AAXX 20091 40751 42960 41802 10111 21054 38496...
# 4  2024-01-20 12:00:00  AAXX 20121 40751 12960 01901 10120 21049 38485...
#
#    temp
# 0   2.6
# 1   3.0
# 2  10.0
# 3  11.1
# 4  12.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1458 non-null   object
#  1   contentmessage  1458 non-null   object
#  2   temp            1433 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 34.3+ KB

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                      date                                     contentmessage  \
# 116   2024-02-03 12:00:00  40751 12660 62101 10041 21042 38434 40187 5500...
# 134   2024-02-06 00:00:00  40751 12660 50000 10034 21017 38409 40128 5701...
# 291   2024-02-25 12:00:00  40751 11510 80000 10000 21007 38443 40195 5600...
# 297   2024-02-26 06:00:00  40751 11540 71901 11004 21036 38463 40236 5301...
# 299   2024-02-26 12:00:00  40751 11656 81802 10018 21041 38448 40214 5701...
# 303   2024-02-27 00:00:00  40751 12960 70000 11026 21066 38469 40242 5500...
# 307   2024-02-27 12:00:00  40751 11556 82001 10006 21047 38464 40239 5600...
# 315   2024-02-28 12:00:00  40751 11558 83301 11002 21048 38457 40231 5701...
# 319   2024-02-29 00:00:00  40751 11620 82101 11030 21040 38461 40240 5400...
# 323   2024-02-29 12:00:00                              AAXX 29121 40751 NIL=
# 331   2024-03-01 12:00:00  40751 12660 32101 10055 21084 38481 40249 5601...
# 428   2024-03-13 15:00:00  40751 42960 00000 10102 21042 38484 40212 5600...
# 429   2024-03-13 18:00:00  40751 12960 00401 10076 21022 38493 40209 5200...
# 430   2024-03-13 21:00:00  40751 42960 00201 10068 21029 38495 40205 5300...
# 431   2024-03-14 00:00:00  40751 12960 00201 10053 21030 38491 40199 5800...
# 432   2024-03-14 03:00:00  40751 42960 00301 10054 21032 38502 40225 5201...
# 433   2024-03-14 06:00:00  40751 12660 62501 10136 21041 38515 40223 5201...
# 434   2024-03-14 09:00:00  40751 42960 21902 10164 21044 38506 40206 5800...
# 435   2024-03-14 12:00:00  40751 12960 02002 10171 21033 38494 40192 5701...
# 436   2024-03-14 15:00:00  40751 42960 00000 10128 21035 38487 40198 5600...
# 496   2023-11-22 00:00:00                              AAXX 22001 40751 NIL=
# 820   2023-10-02 09:00:00  40751 42660 62002 10262 20015 38444 40069 5700...
# 906   2023-10-13 03:00:00  40751 41540 81601 10123 20118 38529 40189 5500...
# 1199  2023-11-18 21:00:00  40751 22960 00301 10094 21002 38470 40147 5400...
# 1230  2023-12-22 15:00:00                              AAXX 22151 40751 NIL=
#
#       temp
# 116    NaN
# 134    NaN
# 291    NaN
# 297    NaN
# 299    NaN
# 303    NaN
# 307    NaN
# 315    NaN
# 319    NaN
# 323    NaN
# 331    NaN
# 428    NaN
# 429    NaN
# 430    NaN
# 431    NaN
# 432    NaN
# 433    NaN
# 434    NaN
# 435    NaN
# 436    NaN
# 496    NaN
# 820    NaN
# 906    NaN
# 1199   NaN
# 1230   NaN

# %%
df1.iloc[110:120]
# Out:
#                     date                                     contentmessage  \
# 110  2024-02-02 18:00:00  AAXX 02181 40751 11658 70000 11006 21012 38387...
# 111  2024-02-02 21:00:00  AAXX 02211 40751 42660 40000 11024 21031 38384...
# 112  2024-02-03 00:00:00  AAXX 03001 40751 12960 40000 11016 21020 38393...
# 113  2024-02-03 03:00:00  AAXX 03031 40751 42960 00000 11032 21045 38404...
# 114  2024-02-03 06:00:00  AAXX 03061 40751 12660 21701 10031 21012 38427...
# 115  2024-02-03 09:00:00  AAXX 03091 40751 42660 62001 10057 21033 38435...
# 116  2024-02-03 12:00:00  40751 12660 62101 10041 21042 38434 40187 5500...
# 117  2024-02-03 15:00:00  AAXX 03151 40751 42660 40201 10015 21043 38447...
# 118  2024-02-03 18:00:00  AAXX 03181 40751 12660 30301 11002 21048 38456...
# 119  2024-02-03 21:00:00  AAXX 03211 40751 42960 00401 11017 21061 38450...
#
#       temp
# 110 -100.6
# 111 -102.4
# 112 -101.6
# 113 -103.2
# 114    3.1
# 115    5.7
# 116    NaN
# 117    1.5
# 118 -100.2
# 119 -101.7

# %%
def extract_temp(s):
    if 'AAXX' in s:
        
        temp_idx = 29
    else:
        temp_idx = 18
    if len(s) >=temp_idx + 5:        
        s = s[temp_idx:temp_idx+5]

        
        if s.isdigit() and s[0] in ['1']:
            if s[1] == '0':
                return float(s[2:]) / 10
            elif s[1] == '1':
                return -float(s[2:]) /10
        else:
            return np.nan
    else:
        return np.nan

# %%
# apply extract_temp function on df
df1 = df.copy()
df1['temp'] = df1['contentmessage'].apply(extract_temp)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1458 non-null   object
#  1   contentmessage  1458 non-null   object
#  2   temp            1455 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 34.3+ KB

# %%
df1.iloc[110:120]
# Out:
#                     date                                     contentmessage  \
# 110  2024-02-02 18:00:00  AAXX 02181 40751 11658 70000 11006 21012 38387...
# 111  2024-02-02 21:00:00  AAXX 02211 40751 42660 40000 11024 21031 38384...
# 112  2024-02-03 00:00:00  AAXX 03001 40751 12960 40000 11016 21020 38393...
# 113  2024-02-03 03:00:00  AAXX 03031 40751 42960 00000 11032 21045 38404...
# 114  2024-02-03 06:00:00  AAXX 03061 40751 12660 21701 10031 21012 38427...
# 115  2024-02-03 09:00:00  AAXX 03091 40751 42660 62001 10057 21033 38435...
# 116  2024-02-03 12:00:00  40751 12660 62101 10041 21042 38434 40187 5500...
# 117  2024-02-03 15:00:00  AAXX 03151 40751 42660 40201 10015 21043 38447...
# 118  2024-02-03 18:00:00  AAXX 03181 40751 12660 30301 11002 21048 38456...
# 119  2024-02-03 21:00:00  AAXX 03211 40751 42960 00401 11017 21061 38450...
#
#      temp
# 110  -0.6
# 111  -2.4
# 112  -1.6
# 113  -3.2
# 114   3.1
# 115   5.7
# 116   4.1
# 117   1.5
# 118  -0.2
# 119  -1.7

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                      date         contentmessage  temp
# 323   2024-02-29 12:00:00  AAXX 29121 40751 NIL=   NaN
# 496   2023-11-22 00:00:00  AAXX 22001 40751 NIL=   NaN
# 1230  2023-12-22 15:00:00  AAXX 22151 40751 NIL=   NaN

# %%
df1.iloc[320:327]
# Out:
#                     date                                     contentmessage  \
# 320  2024-02-29 03:00:00  AAXX 29031 40751 41556 81901 11033 21046 38464...
# 321  2024-02-29 06:00:00  AAXX 29061 40751 11510 81501 11020 21043 38480...
# 322  2024-02-29 09:00:00  AAXX 29091 40751 41540 82201 10003 21053 38476...
# 323  2024-02-29 12:00:00                              AAXX 29121 40751 NIL=
# 324  2024-02-29 15:00:00  AAXX 29151 40751 42660 30000 11002 21075 38476...
# 325  2024-02-29 18:00:00  AAXX 29181 40751 12960 00301 11020 21087 38487...
# 326  2024-02-29 21:00:00  AAXX 29211 40751 42960 00401 11027 21091 38486...
#
#      temp
# 320  -3.3
# 321  -2.0
# 322   0.3
# 323   NaN
# 324  -0.2
# 325  -2.0
# 326  -2.7

# %%
df1['temp'] = df1['temp'].interpolate()

# %%
df1.iloc[320:327]
# Out:
#                     date                                     contentmessage  \
# 320  2024-02-29 03:00:00  AAXX 29031 40751 41556 81901 11033 21046 38464...
# 321  2024-02-29 06:00:00  AAXX 29061 40751 11510 81501 11020 21043 38480...
# 322  2024-02-29 09:00:00  AAXX 29091 40751 41540 82201 10003 21053 38476...
# 323  2024-02-29 12:00:00                              AAXX 29121 40751 NIL=
# 324  2024-02-29 15:00:00  AAXX 29151 40751 42660 30000 11002 21075 38476...
# 325  2024-02-29 18:00:00  AAXX 29181 40751 12960 00301 11020 21087 38487...
# 326  2024-02-29 21:00:00  AAXX 29211 40751 42960 00401 11027 21091 38486...
#
#      temp
# 320 -3.30
# 321 -2.00
# 322  0.30
# 323  0.05
# 324 -0.20
# 325 -2.00
# 326 -2.70

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            1458 non-null   object
#  1   contentmessage  1458 non-null   object
#  2   temp            1458 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 34.3+ KB

# %%
df1.describe().transpose()
# Out:
#        count       mean       std  min  25%  50%   75%   max
# temp  1458.0  10.453052  6.639069 -5.5  5.3  9.8  14.7  29.3

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8, 3), dpi=200)
sns.histplot(data=df1, x='temp', bins=50, kde=True)


plt.show()

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.scatterplot(data=df1, x='date', y='temp')


plt.show()

# %%
df1[df1['temp'] <= -12]
# Out:
# Empty DataFrame
# Columns: [date, contentmessage, temp]
# Index: []

# %%
df1
# Out:
#                      date                                     contentmessage  \
# 0     2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
# 1     2024-01-20 03:00:00  AAXX 20031 40751 42960 00402 10030 21064 38498...
# 2     2024-01-20 06:00:00  AAXX 20061 40751 12960 42201 10100 21044 38506...
# 3     2024-01-20 09:00:00  AAXX 20091 40751 42960 41802 10111 21054 38496...
# 4     2024-01-20 12:00:00  AAXX 20121 40751 12960 01901 10120 21049 38485...
# ...                   ...                                                ...
# 1453  2024-01-19 12:00:00  AAXX 19121 40751 12960 02101 10128 21045 38485...
# 1454  2024-01-19 15:00:00  AAXX 19151 40751 42960 00000 10068 21049 38493...
# 1455  2024-01-19 18:00:00  AAXX 19181 40751 12960 00401 10057 21044 38498...
# 1456  2024-01-19 21:00:00  AAXX 19211 40751 42960 00402 10038 21054 38496...
# 1457  2024-01-20 00:00:00  AAXX 20001 40751 12960 00401 10026 21068 38493...
#
#       temp
# 0      2.6
# 1      3.0
# 2     10.0
# 3     11.1
# 4     12.0
# ...    ...
# 1453  12.8
# 1454   6.8
# 1455   5.7
# 1456   3.8
# 1457   2.6
#
# [1458 rows x 3 columns]

# %%
df_clean = df1[['date', 'temp']]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1458 non-null   object
#  1   temp    1458 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 22.9+ KB

# %%
df_clean.describe().transpose()
# Out:
#        count       mean       std  min  25%  50%   75%   max
# temp  1458.0  10.453052  6.639069 -5.5  5.3  9.8  14.7  29.3

# %%
output_path = 'data_cleaned.xlsx'
df_clean.to_excel(output_path, index=False)

# %%
plt.figure(figsize=(10, 4), dpi=200)
sns.lineplot(data=df1, x='date', y='temp')


plt.show()

# %%
df_clean['date'] = pd.to_datetime(df_clean['date'])
# Out:
# /tmp/ipykernel_147359/4103588557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['date'] = pd.to_datetime(df_clean['date'])

# %%
df_clean
# Out:
#                     date  temp
# 0    2024-01-20 00:00:00   2.6
# 1    2024-01-20 03:00:00   3.0
# 2    2024-01-20 06:00:00  10.0
# 3    2024-01-20 09:00:00  11.1
# 4    2024-01-20 12:00:00  12.0
# ...                  ...   ...
# 1453 2024-01-19 12:00:00  12.8
# 1454 2024-01-19 15:00:00   6.8
# 1455 2024-01-19 18:00:00   5.7
# 1456 2024-01-19 21:00:00   3.8
# 1457 2024-01-20 00:00:00   2.6
#
# [1458 rows x 2 columns]

# %%
df_clean.set_index('date', inplace=True)

# %%
df_clean
# Out:
#                      temp
# date
# 2024-01-20 00:00:00   2.6
# 2024-01-20 03:00:00   3.0
# 2024-01-20 06:00:00  10.0
# 2024-01-20 09:00:00  11.1
# 2024-01-20 12:00:00  12.0
# ...                   ...
# 2024-01-19 12:00:00  12.8
# 2024-01-19 15:00:00   6.8
# 2024-01-19 18:00:00   5.7
# 2024-01-19 21:00:00   3.8
# 2024-01-20 00:00:00   2.6
#
# [1458 rows x 1 columns]

# %%
# df_day = df_clean[['temp']]

# %%
df_day = df_clean.resample('D').mean()

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 183 entries, 2023-09-20 to 2024-03-20
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   temp    183 non-null    float64
# dtypes: float64(1)
# memory usage: 2.9 KB

# %%
df_day.reset_index(inplace=True)

# %%
df_day.to_excel('temp_per_day.xlsx', index=False)

# %%
df_week = df_clean.resample('W').mean()

# %%
df_week
# Out:
#                  temp
# date
# 2023-09-24  21.945000
# 2023-10-01  19.964286
# 2023-10-08  18.737500
# 2023-10-15  17.948214
# 2023-10-22  16.853571
# 2023-10-29  17.391071
# 2023-11-05  14.785714
# 2023-11-12  13.603571
# 2023-11-19  14.054545
# 2023-11-26   8.613158
# 2023-12-03  10.146429
# 2023-12-10   9.853571
# 2023-12-17   8.000000
# 2023-12-24   6.667544
# 2023-12-31   7.833929
# 2024-01-07   6.742857
# 2024-01-14   7.214286
# 2024-01-21   7.342105
# 2024-01-28   6.201786
# 2024-02-04   1.889091
# 2024-02-11   6.845455
# 2024-02-18   9.985714
# 2024-02-25   4.578947
# 2024-03-03   0.247321
# 2024-03-10   7.248214
# 2024-03-17   9.767857
# 2024-03-24  12.788235

# %%
df_week.reset_index(inplace=True)

# %%
df_week.to_excel('temp_per_week.xlsx', index=False)

# %%
# Set up the plot with a specific size and resolution
plt.figure(figsize=(10, 4), dpi=200)

# Create the line plot
sns.lineplot(data=df_week, x='date', y='temp')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add gridlines for better visualization
plt.grid(True, linestyle='--', alpha=0.7)

# Add title and labels to the plot
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')


# Show the plot
plt.show()

# %%
# Set up the plot with a specific size and resolution
plt.figure(figsize=(10, 4), dpi=200)

# Create the line plot
sns.lineplot(data=df_day, x='date', y='temp')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add gridlines for better visualization
plt.grid(True, linestyle='--', alpha=0.7)

# Add title and labels to the plot
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')


# Show the plot
plt.show()

# %%
# Set up the plot with a specific size and resolution
plt.figure(figsize=(10, 4), dpi=200)

# Create the line plot
sns.scatterplot(data=df_day, x='date', y='temp')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Add gridlines for better visualization
plt.grid(True, linestyle='--', alpha=0.7)

# Add title and labels to the plot
plt.title('Temperature Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')


# Show the plot
plt.show()

# %%
df_clean.reset_index(inplace=True)
