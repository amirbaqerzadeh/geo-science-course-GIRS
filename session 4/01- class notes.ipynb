# %% [markdown]
# # Session 4: Pandas

# %%
import numpy as np
import pandas as pd

# %%
my_index = ['Reza', 'Nikan', 'Sara']
my_data = [12, 16, 18]

# %%
my_serie = pd.Series(data=my_data)

# %%
my_serie
# Out:
# 0    12
# 1    16
# 2    18
# dtype: int64

# %%
type(my_serie)
# Out:
# pandas.core.series.Series

# %%
my_serie = pd.Series(data=my_data, index=my_index)

# %%
print(my_serie)
# Out:
# Reza     12
# Nikan    16
# Sara     18
# dtype: int64

# %%
df = pd.DataFrame(data=my_data, index=my_index,  )

# %%
df
# Out:
#         0
# Reza   12
# Nikan  16
# Sara   18

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
my_data_dict = {'name':['Amir', 'Kian', 'Reza'],
           'age':[19, 21, 15], 
           'city':['Tehran', 'Shiraz', 'Sari']}

# %%
df = pd.DataFrame(data=my_data_dict)

# %%
df
# Out:
#    name  age    city
# 0  Amir   19  Tehran
# 1  Kian   21  Shiraz
# 2  Reza   15    Sari

# %%
df.to_excel('test_df.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.to_excel('test_df.xlsx', index=False)
#
# File /mnt/mini/envs/weather/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /mnt/mini/envs/weather/lib/python3.10/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 535.7 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...

# %%
df.to_excel('test_df.xlsx', index=False)

# %%
pwd
# Out:
# '/home/amir/Desktop/session 3'

# %%
file_path = '/home/amir/Desktop/session 3/tips.csv'
df_1 = pd.read_csv(file_path)

# %%
df_1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_1.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df_1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df_1.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df_1.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df_1['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df_1['total_bill'])
# Out:
# pandas.core.series.Series

# %%
df_1['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
a = df_1['smoker']

# %%
len(a)
# Out:
# 244

# %%
df_1['smo ke']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /mnt/mini/envs/weather/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'smo ke'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_1['smo ke']
#
# ...

# %%
df_1.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
my_cols = ['total_bill', 'smoker', 'day']
df_2 = df_1[my_cols]

# %%
df_2.head()
# Out:
#    total_bill smoker  day
# 0       16.99     No  Sun
# 1       10.34     No  Sun
# 2       21.01     No  Sun
# 3       23.68     No  Sun
# 4       24.59     No  Sun

# %%
# df_2 = df_1[['total_bill', 'smoker', 'day']]

# %%
df_1.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df_1['tip_percentage'] = round((df_1['tip'] / df_1['total_bill']) * 100, 2)

# %%
df_1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
df_1.drop('tip_percentage')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df_1.drop('tip_percentage')
#
# File /mnt/mini/envs/weather/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df_1.drop('tip_percentage', axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df_1.drop('tip_percentage', axis=1, inplace=True)

# %%
df_1.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959

# %%
df_1.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df_1.set_index("Payment ID", inplace=True)

# %%
df_1
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df_1.reset_index(inplace=True)

# %%
df_1
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df_corr = df_1[['total_bill', 'price_per_person', 'tip']]

# %%
df_corr.corr()
# Out:
#                   total_bill  price_per_person       tip
# total_bill          1.000000          0.647554  0.675734
# price_per_person    0.647554          1.000000  0.347405
# tip                 0.675734          0.347405  1.000000

# %%
df_1.head(2)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230

# %%
high_bills_bools = df_1['total_bill'] > 30
# high_bills_bools[:20]
df_1[high_bills_bools]
# Out:
#     Payment ID  total_bill    tip     sex smoker   day    time  size  \
# 11     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 39     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 44     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 56     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 83    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 95     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
high_bill_df = df_1[df_1['total_bill'] > 30]

# %%
df_no_smoke = df_1[df_1['smoker'] == "No"]

# %%
df_no_smoke
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 235    Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df_1['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df_1['smoker'].value_counts(ascending=True)
# Out:
# smoker
# Yes     93
# No     151
# Name: count, dtype: int64

# %%
df_1['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df_1['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
condition = (df_1['total_bill'] > 30) & (df_1['day'] == 'Sat')
a = df_1[condition]

# %%
a['Payment ID']
# Out:
# 23      Sat239
# 39     Sat6373
# 56     Sat8903
# 59     Sat8139
# 102    Sat6240
# 170    Sat1954
# 207    Sat4505
# 210    Sat8361
# 212    Sat4590
# 219    Sat8863
# 237    Sat2929
# 238    Sat9777
# Name: Payment ID, dtype: object

# %%
df_1.head(2)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230

# %%
df_1['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
def rate_price(price):
    if price < 10:
        return "$"
    elif price >= 10 and price < 30:
        return "$$"
    else:
        return "$$$"

# %%
df_1['rate_price'] = df_1['total_bill'].apply(rate_price)

# %%
df_1.head(15)
# Out:
#    Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0     Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1     Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2     Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3     Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4     Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
# 5     Sun9679       25.29  4.71    Male     No  Sun  Dinner     4
# 6     Sun5985        8.77  2.00    Male     No  Sun  Dinner     2
# 7     Sun8157       26.88  3.12    Male     No  Sun  Dinner     4
# 8     Sun6820       15.04  1.96    Male     No  Sun  Dinner     2
# 9     Sun3775       14.78  3.23    Male     No  Sun  Dinner     2
# 10    Sun2546       10.27  1.71    Male     No  Sun  Dinner     2
# 11    Sun6686       35.26  5.00  Female     No  Sun  Dinner     4
# 12    Sun1300       15.42  1.57    Male     No  Sun  Dinner     2
# ...
